# %%
print("Hello,shall we start Our Day1")
# Out:
# Hello,shall we start Our Day1

# %%
name="Suresh"
age=22
City="vzm"

# %%
print(name,type(name))
print(age,type(age))
print(City,type(City))
# Out:
# Suresh <class 'str'>
# 22 <class 'int'>
# vzm <class 'str'>

# %%
marks = [85, 90, 72, 60, 45]

# %%
print(marks)
# Out:
# [85, 90, 72, 60, 45]

# %%
print(marks[0])
# Out:
# 85

# %%
len(marks)
# Out:
# 5

# %%
me={
    "Name":"Suresh",
    "Age":22,
    "City":"Vzm"

}

# %%
print(me)
# Out:
# {'Name': 'Suresh', 'Age': 22, 'City': 'Vzm'}

# %%
print(me["Name"])
# Out:
# Suresh

# %%
print(age)
# Out:
# 22

# %%
x = 33

if x % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
bio = {
    "Name": "Suresh",
    "Age": 22,
    "City": "Vizianagaram",
    "Favourite Skill": "Python",
    "Goal": "Data Analyst"
}

# %%
for key,value in bio.items():
  print(key +":",value)
# Out:
# Name: Suresh
# Age: 22
# City: Vizianagaram
# Favourite Skill: Python
# Goal: Data Analyst

# %%
marks=[10,20,50,67,77]

# %%
print(marks[1])
# Out:
# 20

# %%
len(marks)
# Out:
# 5

# %%
marks.append(14)

# %%
marks
# Out:
# [10, 20, 50, 67, 77, 14]

# %%
marks.insert(2,55)

# %%
marks
# Out:
# [10, 20, 55, 50, 67, 77, 14]

# %%
marks.remove(50)

# %%
marks.pop(3)
# Out:
# 67

# %%
marks[1:5]
# Out:
# [20, 55, 77, 14]

# %%
marks[:3]
# Out:
# [10, 20, 55]

# %%
for m in marks:
  print(m)
# Out:
# 10
# 20
# 55
# 77
# 14

# %%
student={"name":"suresh","city":"vzm","age":22}

# %%
student
# Out:
# {'name': 'suresh', 'city': 'vzm', 'age': 22}

# %%
print(student["name"])
# Out:
# suresh

# %%
print(student["age"])
# Out:
# 22

# %%
student["skill"]="python"

# %%
student["age"] = 23

# %%
del student["city"]

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'skill'])

# %%
student.values()
# Out:
# dict_values(['suresh', 23, 'python'])

# %%
for key in student:
  print(key)
# Out:
# name
# age
# skill

# %%
for value in student.values():
  print(value)
# Out:
# suresh
# 23
# python

# %%
for key,value in student.items():
  print(key,":",value)
# Out:
# name : suresh
# age : 23
# skill : python

# %%
employee = {
    "id": 101,
    "name": "Suresh",
    "role": "Data Analyst"
}

employee["salary"] = 30000
employee["role"] = "Junior Data Analyst"

for k, v in employee.items():
    print(k, ":", v)
# Out:
# id : 101
# name : Suresh
# role : Junior Data Analyst
# salary : 30000

# %%
def greet():
  print("hello")

# %%
def greet():
  print("welcome to data analysis")

greet()
# Out:
# welcome to data analysis

# %%
def add(a,b):
   print(a + b)

add(10,33)
# Out:
# 43

# %%
def average(a,b):
  return (a+b)/2

result =average(10,20)
print(result)
# Out:
# 15.0

# %%
def total_marks(marks):
  return sum(marks)

marks=[85,66,55,44,22]
print(total_marks(marks))
# Out:
# 272

# %%
def total_exp(exp):
  return sum(exp)

exp=[111,222,333,444,555]
print(total_exp(exp))
# Out:
# 1665

# %%
print("your final score is %d")
# Out:
# your final score is %d

# %%
#Day-3, Pandas

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data={
    "name":["suresh","Ramesh","pippop","Bluetar"],
    "Age":[22,33,44,55],
    "city":["vzm","gpm","nlr","pvp"]
}

# %%
pd.DataFrame(data)
# Out:
#       name  Age city
# 0   suresh   22  vzm
# 1   Ramesh   33  gpm
# 2   pippop   44  nlr
# 3  Bluetar   55  pvp

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#       name  Age city
# 0   suresh   22  vzm
# 1   Ramesh   33  gpm
# 2   pippop   44  nlr
# 3  Bluetar   55  pvp

# %%
df.tail(4)
# Out:
#       name  Age city
# 0   suresh   22  vzm
# 1   Ramesh   33  gpm
# 2   pippop   44  nlr
# 3  Bluetar   55  pvp

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['name', 'Age', 'city'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df["city"]
# Out:
# 0    vzm
# 1    gpm
# 2    nlr
# 3    pvp
# Name: city, dtype: object

# %%
df.iloc[0]
# Out:
# name    suresh
# Age         22
# city       vzm
# Name: 0, dtype: object

# %%
import pandas as pd
data={
    "name":["suresh","raj","gopi"],"age":[22,23,21],"city":["vzm","chennai","hyderabad"]
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#      name  age       city
# 0  suresh   22        vzm
# 1     raj   23    chennai
# 2    gopi   21  hyderabad

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.shape
# Out:
# (3, 3)

# %%
import pandas as pd
from io import StringIO

csv_data = """Name,Marks,City
Suresh,85,Vizianagaram
Ravi,90,Hyderabad
Anil,78,Chennai
"""

df = pd.read_csv(StringIO(csv_data))
print(df)
print(df.info())
# Out:
#      Name  Marks          City
# 0  Suresh     85  Vizianagaram
# 1    Ravi     90     Hyderabad
# 2    Anil     78       Chennai
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
df.shape
# Out:
# (3, 3)

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
df[["Name","City"]]
# Out:
#      Name          City
# 0  Suresh  Vizianagaram
# 1    Ravi     Hyderabad
# 2    Anil       Chennai

# %%
df[df["Marks"]>80]
# Out:
#      Name  Marks          City
# 0  Suresh     85  Vizianagaram
# 1    Ravi     90     Hyderabad

# %%
df[df["City"]=="Vizianagaram"]
# Out:
#      Name  Marks          City
# 0  Suresh     85  Vizianagaram

# %%
print(df[df["City"] == "Chennai"])
# Out:
#    Name  Marks     City
# 2  Anil     78  Chennai

# %%
import pandas as pd
from io import StringIO

csv_data = """Name,Marks,City
Suresh,85,Vizianagaram
Ravi,,Hyderabad
Anil,78,Chennai
Suresh,85,Vizianagaram
"""

# %%
df=pd.read_csv(StringIO(csv_data))

# %%
df
# Out:
#      Name  Marks          City
# 0  Suresh   85.0  Vizianagaram
# 1    Ravi    NaN     Hyderabad
# 2    Anil   78.0       Chennai
# 3  Suresh   85.0  Vizianagaram

# %%
df.isnull()
# Out:
#     Name  Marks   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3  False  False  False

# %%
df.isnull().sum()
# Out:
# Name     0
# Marks    1
# City     0
# dtype: int64

# %%
df.dropna()
# Out:
#      Name  Marks          City
# 0  Suresh   85.0  Vizianagaram
# 2    Anil   78.0       Chennai
# 3  Suresh   85.0  Vizianagaram

# %%
df.fillna(0)
# Out:
#      Name  Marks          City
# 0  Suresh   85.0  Vizianagaram
# 1    Ravi    0.0     Hyderabad
# 2    Anil   78.0       Chennai
# 3  Suresh   85.0  Vizianagaram

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Name  Marks          City
# 0  Suresh   85.0  Vizianagaram
# 1    Ravi    NaN     Hyderabad
# 2    Anil   78.0       Chennai

# %%
df.sort_values(by="Marks",ascending=False)
# Out:
#      Name  Marks          City
# 0  Suresh   85.0  Vizianagaram
# 3  Suresh   85.0  Vizianagaram
# 2    Anil   78.0       Chennai
# 1    Ravi    NaN     Hyderabad

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Name  Marks          City
# 0  Suresh   85.0  Vizianagaram
# 1    Ravi    NaN     Hyderabad
# 2    Anil   78.0       Chennai
# 3  Suresh   85.0  Vizianagaram>

# %%
df_clean = df.drop_duplicates()

# %%
df_clean.describe()
# Out:
#            Marks
# count   2.000000
# mean   81.500000
# std     4.949747
# min    78.000000
# 25%    79.750000
# 50%    81.500000
# 75%    83.250000
# max    85.000000
